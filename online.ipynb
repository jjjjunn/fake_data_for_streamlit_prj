# %% [markdown]
# ## 재활용 온라인 키워드 광고 데이터 만들기

# %%
# 필요한 라이브러리 import
import pandas as pd
import numpy as np
import random

# %%
# 날짜 범위 생성
date_range = pd.date_range(start="2023-01-01", end="2024-12-31", freq='D')

# 대표 키워드 10개 설정
recycling_keywords = [
    "재활용 방법", "재활용 분리 배출", "재활용 쓰레기", "재활용 아이디어", 
    "재활용 센터", "재활용 법률", "플라스틱 재활용", "재활용의 중요성", 
    "재활용 교육", "재활용 통계"
]

# 결과를 저장할 리스트 초기화
raw_data = {
    "날짜": [],
    "키워드": [],
    "노출수": [],
    "클릭수": []
}

# 날짜별로 여러 개의 키워드를 할당
for date in date_range:
    num_keywords = random.randint(1, len(recycling_keywords))  # 키워드 수 무작위 선택
    chosen_keywords = random.sample(recycling_keywords, num_keywords)  # 무작위로 키워드 선택

    for keyword in chosen_keywords:
        exposures = random.randint(1, 10_000)  # 각 키워드에 대해 랜덤으로 노출수 생성

        # 클릭수는 노출수 이하로 설정
        clicks = random.randint(0, min(exposures, 300))  # 클릭수는 노출수 및 300 이하
        
        # 데이터 추가
        raw_data["날짜"].append(date)  # 날짜 추가
        raw_data["키워드"].append(keyword)  # 선택된 키워드 추가
        raw_data["노출수"].append(exposures)  # 노출수 추가
        raw_data["클릭수"].append(clicks)  # 클릭수 추가

data = pd.DataFrame(raw_data)  # DataFrame 생성
data.head(15)  # 상위 15개 데이터 출력
# Out:
#            날짜        키워드   노출수  클릭수
# 0  2023-01-01   플라스틱 재활용  3365  186
# 1  2023-01-01    재활용 쓰레기   810   56
# 2  2023-01-01     재활용 방법  2407  168
# 3  2023-01-01     재활용 법률  7290   68
# 4  2023-01-01   재활용 아이디어  4282   60
# 5  2023-01-01     재활용 교육  3763   16
# 6  2023-01-01   재활용의 중요성  1747  179
# 7  2023-01-01     재활용 센터  2784  292
# 8  2023-01-01     재활용 통계  6348  255
# 9  2023-01-01  재활용 분리 배출  6239  145
# 10 2023-01-02   재활용 아이디어  4185  255
# 11 2023-01-02     재활용 통계  5437  297
# 12 2023-01-02     재활용 법률  6852   75
# 13 2023-01-02   재활용의 중요성  3039  280
# 14 2023-01-02     재활용 센터  7226  132

# %%
# 클릭률, 클릭비용, 총비용 열 생성
data["클릭률"] = (data["클릭수"] / data["노출수"]
data["클릭비용"] = [random.randint(0, 200) for _ in range(len(data["노출수"]))] # 클릭비용(CPC)의 경우, 랜덤으로 생성
data["총비용"] = data["클릭수"] * data["클릭비용"]

data.head()
# Out:
#           날짜       키워드   노출수  클릭수       클릭률  클릭비용    총비용
# 0 2023-01-01  플라스틱 재활용  3365  186  0.055275    10   1860
# 1 2023-01-01   재활용 쓰레기   810   56  0.069136    76   4256
# 2 2023-01-01    재활용 방법  2407  168  0.069796    45   7560
# 3 2023-01-01    재활용 법률  7290   68  0.009328   163  11084
# 4 2023-01-01  재활용 아이디어  4282   60  0.014012    18   1080

# %%
# 데이터 정보 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3924 entries, 0 to 3923
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      3924 non-null   datetime64[ns]
#  1   키워드     3924 non-null   object
#  2   노출수     3924 non-null   int64
#  3   클릭수     3924 non-null   int64
#  4   클릭률     3924 non-null   float64
#  5   클릭비용    3924 non-null   int64
#  6   총비용     3924 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 214.7+ KB

# %%
# 전환수, 전환율 구하기
data["전환수"] = [random.randint(0, min(clicks, 10)) for _ in range(len(data["날짜"]))] # 전환수의 경우, 클릭수보다 낮게
data["전환율"] = (data["전환수"] / data["클릭수"]) * 100 # 전환율은 클릭 나누기 전환

data.tail()
# Out:
#              날짜       키워드   노출수  클릭수       클릭률  클릭비용    총비용  전환수        전환율
# 3919 2024-12-30  플라스틱 재활용  7495   13  0.001734    65    845    8  61.538462
# 3920 2024-12-30    재활용 법률  8993  217  0.024130   138  29946    3   1.382488
# 3921 2024-12-30    재활용 센터  4929  242  0.049097   163  39446    0   0.000000
# 3922 2024-12-30    재활용 교육  2049  175  0.085408    18   3150    4   2.285714
# 3923 2024-12-31  플라스틱 재활용  3757  173  0.046047    27   4671    8   4.624277

# %%
# CSV 파일로 저장
data.to_csv("recycling_online.csv", index=False, encoding='utf-8-sig')  # index=False는 인덱스 열을 저장하지 않도록 설정
